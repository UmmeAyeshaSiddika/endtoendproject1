# %% [markdown]
# # Ingest the data

# %%
import pandas as pd

# %%
data = pd.read_csv(r"D:\ineuron all\practice\endtoendproject1\notebooks\data\gemstone.csv")

# %%
data
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 0            0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33
# 1            1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12
# 2            2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73
# 3            3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41
# 4            4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61
# ...        ...    ...        ...   ...     ...    ...    ...   ...   ...
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 0       4.55  13619
# 1       5.05  13387
# 2       3.50   2772
# ...

# %%
data.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
data.tail()
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 193568  2.67   1130
# 193569  3.47   2874
# 193570  3.62   3036
# 193571  2.81    681
# 193572  3.48   2258

# %%
data.sample(5)
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 64453    64453   0.41       Good     J     VS1   59.1   61.0  4.95  4.97
# 27762    27762   0.31      Ideal     I     VS1   60.7   57.0  4.41  4.44
# 178525  178525   0.30      Ideal     E     VS2   61.4   56.0  4.33  4.37
# 95033    95033   0.33      Ideal     F     SI2   62.1   55.0  4.44  4.48
# 149437  149437   1.00  Very Good     E     SI1   62.2   59.0  6.39  6.36
#
#            z  price
# 64453   2.93    735
# 27762   2.68    558
# 178525  2.67    844
# 95033   2.77    572
# 149437  3.96   5208

# %%
data.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
data.drop(labels=["id"],axis=1)
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]

# %%
data.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (193573, 11)

# %%
# cat vs num
data.dtypes == "Object"
# Out:
# id         False
# carat      False
# cut        False
# color      False
# clarity    False
# depth      False
# table      False
# x          False
# y          False
# z          False
# price      False
# dtype: bool

# %%
categorical_columns = data.columns[data.dtypes=="object"]

# %%
numerical_columns = data.columns[data.dtypes!="object"]

# %%
data[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
data[numerical_columns].describe()
# Out:
#                   id          carat          depth          table  \
# count  193573.000000  193573.000000  193573.000000  193573.000000
# mean    96786.000000       0.790688      61.820574      57.227675
# std     55879.856166       0.462688       1.081704       1.918844
# min         0.000000       0.200000      52.100000      49.000000
# 25%     48393.000000       0.400000      61.300000      56.000000
# 50%     96786.000000       0.700000      61.900000      57.000000
# 75%    145179.000000       1.030000      62.400000      58.000000
# max    193572.000000       3.500000      71.600000      79.000000
#
#                    x              y              z          price
# count  193573.000000  193573.000000  193573.000000  193573.000000
# mean        5.715312       5.720094       3.534246    3969.155414
# std         1.109422       1.102333       0.688922    4034.374138
# min         0.000000       0.000000       0.000000     326.000000
# ...

# %%
data[numerical_columns].describe().T
# Out:
#           count          mean           std    min       25%       50%  \
# id     193573.0  96786.000000  55879.856166    0.0  48393.00  96786.00
# carat  193573.0      0.790688      0.462688    0.2      0.40      0.70
# depth  193573.0     61.820574      1.081704   52.1     61.30     61.90
# table  193573.0     57.227675      1.918844   49.0     56.00     57.00
# x      193573.0      5.715312      1.109422    0.0      4.70      5.70
# y      193573.0      5.720094      1.102333    0.0      4.71      5.72
# z      193573.0      3.534246      0.688922    0.0      2.90      3.53
# price  193573.0   3969.155414   4034.374138  326.0    951.00   2401.00
#
#              75%        max
# id     145179.00  193572.00
# carat       1.03       3.50
# depth      62.40      71.60
# table      58.00      79.00
# x           6.51       9.65
# y           6.51      10.01
# z           4.03      31.30
# price    5408.00   18818.00

# %%
data[categorical_columns].value_counts()
# Out:
# cut    color  clarity
# Ideal  E      VS2        5490
#        G      VS2        5131
#               VS1        5107
#        E      SI1        4309
#        F      VS2        4235
#                          ...
#        J      I1            2
# Fair   G      IF            2
# Good   J      IF            1
# Fair   D      VVS1          1
#        F      IF            1
# Name: count, Length: 276, dtype: int64

# %%
data[categorical_columns]["cut"].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
data[categorical_columns]["color"].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
data[categorical_columns]["clarity"].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
data[numerical_columns].describe().T
# Out:
#           count          mean           std    min       25%       50%  \
# id     193573.0  96786.000000  55879.856166    0.0  48393.00  96786.00
# carat  193573.0      0.790688      0.462688    0.2      0.40      0.70
# depth  193573.0     61.820574      1.081704   52.1     61.30     61.90
# table  193573.0     57.227675      1.918844   49.0     56.00     57.00
# x      193573.0      5.715312      1.109422    0.0      4.70      5.70
# y      193573.0      5.720094      1.102333    0.0      4.71      5.72
# z      193573.0      3.534246      0.688922    0.0      2.90      3.53
# price  193573.0   3969.155414   4034.374138  326.0    951.00   2401.00
#
#              75%        max
# id     145179.00  193572.00
# carat       1.03       3.50
# depth      62.40      71.60
# table      58.00      79.00
# x           6.51       9.65
# y           6.51      10.01
# z           4.03      31.30
# price    5408.00   18818.00

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure (figsize=(8,6))

# %%
for col in numerical_columns:
    sns.histplot(data=data,x=col,kde=True)
    print("\n")
    plt.show()

# %%
# Categorical data
# Assignment is you have to take all the categorical col and you need to plot bar plot or count

# %%
sns.heatmap(data[numerical_columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['id', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y',
#        'z', 'price'],
#       dtype='object')

# %% [markdown]
# # encoding

# %%
data["clarity"].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
data["cut"].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
data["color"].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %% [markdown]
# # Mapping

# %%
cut_map = {"Fair":1,"Good":2,"Very good":3,"Premium":4,"Ideal":5}

# %%
clarity_map = {"I1":1,"SI2":2,"SI1":1,"VS2":4,"VS1":5,"WS2":6,"WS1":7,"IF":8}

# %%
color_map = {"D":1,"E":2,"F":3,"G":4,"H":5,"I":6,"J":7}

# %%
data["cut"] = data["cut"].map(cut_map)

# %%
data["clarity"] = data["cut"].map(clarity_map)

# %%
data["color"] = data["cut"].map(color_map)

# %%
data.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0   1.52  4.0    NaN      NaN   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  NaN    NaN      NaN   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70  5.0    NaN      NaN   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32  5.0    NaN      NaN   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70  4.0    NaN      NaN   62.6   59.0  7.65  7.61  4.77  14453

# %%
data.drop(labels="id",axis=1,inplace=True)

# %%
data
# Out:
#         carat  cut  color  clarity  depth  table     x     y     z  price
# 0        1.52  4.0    NaN      NaN   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03  NaN    NaN      NaN   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70  5.0    NaN      NaN   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32  5.0    NaN      NaN   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70  4.0    NaN      NaN   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 193568   0.31  5.0    NaN      NaN   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70  4.0    NaN      NaN   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73  NaN    NaN      NaN   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34  NaN    NaN      NaN   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71  2.0    NaN      NaN   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]
